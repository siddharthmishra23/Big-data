# %% [markdown]
# ### Streaming application using Spark Structured Streaming (55%)

# %% [markdown]
# #### Write code to SparkSession is created using a SparkConf object, which would use two local cores with a proper application name, and use UTC as the timezone.

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.0.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.0.0 pyspark-shell'
from pyspark import SparkConf # Spark
from pyspark.sql import SparkSession

# setting up spark session
spark_conf = SparkConf()\
            .setMaster("local[2]")\
            .setAppName("Spark Streaming")\
            .set("spark.sql.session.timeZone", "UTC")


spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/lib/python3.8/dist-packages/pyspark/jars/spark-unsafe_2.12-3.0.0.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Ivy Default Cache set to: /srv/home/smis0018/.ivy2/cache
# The jars for the packages stored in: /srv/home/smis0018/.ivy2/jars
# :: loading settings :: url = jar:file:/usr/local/lib/python3.8/dist-packages/pyspark/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# org.apache.spark#spark-streaming-kafka-0-10_2.12 added as a dependency
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-ef0b5d5d-148a-415d-a5b7-d96707411971;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-streaming-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.kafka#kafka-clients;2.4.1 in central
# 	found com.github.luben#zstd-jni;1.4.4-3 in central
# 	found org.lz4#lz4-java;1.7.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.7.5 in central
# 	found org.slf4j#slf4j-api;1.7.30 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.6.2 in central
# :: resolution report :: resolve 996ms :: artifacts dl 14ms
# 	:: modules in use:
# 	com.github.luben#zstd-jni;1.4.4-3 from central in [default]
# 	org.apache.commons#commons-pool2;2.6.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.apache.spark#spark-streaming-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.0.0 from central in [default]
# 	org.lz4#lz4-java;1.7.1 from central in [default]
# 	org.slf4j#slf4j-api;1.7.30 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.7.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   10  |   0   |   0   |   0   ||   10  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-ef0b5d5d-148a-415d-a5b7-d96707411971
# 	confs: [default]
# 	0 artifacts copied, 10 already retrieved (0kB/19ms)
# 22/10/23 05:48:47 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %% [markdown]
# #### Use the same topic names from the Kafka producer in Task 1, ingest the streaming data into Spark Streaming and assume all data coming in String format.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.functions import split
from pyspark.sql import functions as F
from pyspark.sql.types import *

# reading publiser's publised data
df_cust = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", 'localhost:9092') \
    .option("subscribe", "customer_data") \
    .load()

# %%
# reading publiser's publised data
df_bur = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", 'localhost:9092') \
    .option("subscribe", "bureau_data") \
    .load()

# %% [markdown]
# ### Then the streaming data format should be transformed into the proper formats following the metadata file schema, similar to assignment 2A. Then use 'ts' column as the watermark and set the delay threshold to 5 seconds.

# %%
#Define the schema for the structured datastream received ref class notes : week 10 
cust_schema = ArrayType(StructType([    
    StructField("ID", IntegerType(), True),
    StructField("Frequency", StringType(), True),
    StructField("InstlmentMode", StringType(), True),
    StructField("LoanStatus", StringType(), True),
    StructField("PaymentMode", StringType(), True),
    StructField("BranchID", StringType(), True),
    StructField("Area", StringType(), True),
    StructField("Tenure", IntegerType(), True),
    StructField("AssetCost", IntegerType(), True),
    StructField("AmountFinance", DoubleType(), True),
    StructField("DisbursalAmount", DoubleType(), True),
    StructField("EMI", DoubleType(), True),
    StructField("DisbursalDate", StringType(), True),
    StructField("MaturityDAte", StringType(), True),
    StructField("AuthDate", StringType(), True),
    StructField("AssetID", StringType(), True),
    StructField("ManufacturerID", StringType(), True),
    StructField("SupplierID", StringType(), True),
    StructField("LTV", DoubleType(), True),
    StructField("SEX", StringType(), True),
    StructField("AGE", IntegerType(), True),
    StructField("MonthlyIncome", DoubleType(), True),
    StructField("City", StringType(), True),
    StructField("State", StringType(), True),
    StructField("ZiPCODE", IntegerType(), True),
    StructField("Top-up Month", StringType(), True),
    StructField('ts', TimestampType(), True)          
]))
# custom schema
bur_schema = ArrayType(StructType([    
    StructField("ID", IntegerType(), True),
    StructField("SELF-INDICATOR", StringType(), True),
    StructField("MATCH-TYPE", StringType(), True),
    StructField("ACCT-TYPE", StringType(), True),
    StructField("CONTRIBUTOR-TYPE", StringType(), True),
    StructField("DATE-REPORTED", StringType(), True),
    StructField("OWNERSHIP-IND", StringType(), True),
    StructField("ACCOUNT-STATUS", StringType(), True),
    StructField("DISBURSED-DT", StringType(), True),
    StructField("CLOSE-DT", StringType(), True),
    StructField("LAST-PAYMENT-DATE", StringType(), True),
    StructField("CREDIT-LIMIT/SANC AMT", StringType(), True),
    StructField("DISBURSED-AMT/HIGH CREDIT", StringType(), True),
    StructField("INSTALLMENT-AMT", StringType(), True),
    StructField("CURRENT-BAL", StringType(), True),
    StructField("INSTALLMENT-FREQUENCY", StringType(), True),
    StructField("OVERDUE-AMT", StringType(), True),
    StructField("WRITE-OFF-AMT", IntegerType(), True),
    StructField("ASSET_CLASS", StringType(), True),
    StructField("REPORTED DATE - HIST", StringType(), True),
    StructField("DPD - HIST", StringType(), True),
    StructField("CUR BAL - HIST", StringType(), True),
    StructField("AMT OVERDUE - HIST", StringType(), True),
    StructField("AMT PAID - HIST", StringType(), True),
    StructField("TENURE", IntegerType(), True),
    StructField('ts', TimestampType(), True)            
]))

# %%
# selecting value and casting it to string from the schema
df_cust = df_cust.select(F.from_json(F.col("value").cast("string"), cust_schema).alias('parsed_value'))
df_bur = df_bur.select(F.from_json(F.col("value").cast("string"), bur_schema).alias('parsed_value'))
# Out:
# 22/10/23 05:48:52 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df_cust.printSchema()
# Out:
# root
#  |-- parsed_value: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ID: integer (nullable = true)
#  |    |    |-- Frequency: string (nullable = true)
#  |    |    |-- InstlmentMode: string (nullable = true)
#  |    |    |-- LoanStatus: string (nullable = true)
#  |    |    |-- PaymentMode: string (nullable = true)
#  |    |    |-- BranchID: string (nullable = true)
#  |    |    |-- Area: string (nullable = true)
#  |    |    |-- Tenure: integer (nullable = true)
#  |    |    |-- AssetCost: integer (nullable = true)
#  |    |    |-- AmountFinance: double (nullable = true)
#  |    |    |-- DisbursalAmount: double (nullable = true)
#  |    |    |-- EMI: double (nullable = true)
#  |    |    |-- DisbursalDate: string (nullable = true)
#  |    |    |-- MaturityDAte: string (nullable = true)
#  |    |    |-- AuthDate: string (nullable = true)
#  |    |    |-- AssetID: string (nullable = true)
#  |    |    |-- ManufacturerID: string (nullable = true)
#  |    |    |-- SupplierID: string (nullable = true)
#  |    |    |-- LTV: double (nullable = true)
#  |    |    |-- SEX: string (nullable = true)
#  |    |    |-- AGE: integer (nullable = true)
#  |    |    |-- MonthlyIncome: double (nullable = true)
#  |    |    |-- City: string (nullable = true)
#  |    |    |-- State: string (nullable = true)
#  |    |    |-- ZiPCODE: integer (nullable = true)
#  |    |    |-- Top-up Month: string (nullable = true)
#  |    |    |-- ts: timestamp (nullable = true)

# %%
df_bur.printSchema()
# Out:
# root
#  |-- parsed_value: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ID: integer (nullable = true)
#  |    |    |-- SELF-INDICATOR: string (nullable = true)
#  |    |    |-- MATCH-TYPE: string (nullable = true)
#  |    |    |-- ACCT-TYPE: string (nullable = true)
#  |    |    |-- CONTRIBUTOR-TYPE: string (nullable = true)
#  |    |    |-- DATE-REPORTED: string (nullable = true)
#  |    |    |-- OWNERSHIP-IND: string (nullable = true)
#  |    |    |-- ACCOUNT-STATUS: string (nullable = true)
#  |    |    |-- DISBURSED-DT: string (nullable = true)
#  |    |    |-- CLOSE-DT: string (nullable = true)
#  |    |    |-- LAST-PAYMENT-DATE: string (nullable = true)
#  |    |    |-- CREDIT-LIMIT/SANC AMT: string (nullable = true)
#  |    |    |-- DISBURSED-AMT/HIGH CREDIT: string (nullable = true)
#  |    |    |-- INSTALLMENT-AMT: string (nullable = true)
#  |    |    |-- CURRENT-BAL: string (nullable = true)
#  |    |    |-- INSTALLMENT-FREQUENCY: string (nullable = true)
#  |    |    |-- OVERDUE-AMT: string (nullable = true)
#  |    |    |-- WRITE-OFF-AMT: integer (nullable = true)
#  |    |    |-- ASSET_CLASS: string (nullable = true)
#  |    |    |-- REPORTED DATE - HIST: string (nullable = true)
#  |    |    |-- DPD - HIST: string (nullable = true)
#  |    |    |-- CUR BAL - HIST: string (nullable = true)
#  |    |    |-- AMT OVERDUE - HIST: string (nullable = true)
#  |    |    |-- AMT PAID - HIST: string (nullable = true)
#  |    |    |-- TENURE: integer (nullable = true)
#  |    |    |-- ts: timestamp (nullable = true)

# %%
# as we have nested column we are using explode to flatten it
df_cust = df_cust.select(F.explode(F.col("parsed_value")).alias('unnested_value'))
df_bur = df_bur.select(F.explode(F.col("parsed_value")).alias('unnested_value'))

# %%
df_cust.printSchema()
# Out:
# root
#  |-- unnested_value: struct (nullable = true)
#  |    |-- ID: integer (nullable = true)
#  |    |-- Frequency: string (nullable = true)
#  |    |-- InstlmentMode: string (nullable = true)
#  |    |-- LoanStatus: string (nullable = true)
#  |    |-- PaymentMode: string (nullable = true)
#  |    |-- BranchID: string (nullable = true)
#  |    |-- Area: string (nullable = true)
#  |    |-- Tenure: integer (nullable = true)
#  |    |-- AssetCost: integer (nullable = true)
#  |    |-- AmountFinance: double (nullable = true)
#  |    |-- DisbursalAmount: double (nullable = true)
#  |    |-- EMI: double (nullable = true)
#  |    |-- DisbursalDate: string (nullable = true)
#  |    |-- MaturityDAte: string (nullable = true)
#  |    |-- AuthDate: string (nullable = true)
#  |    |-- AssetID: string (nullable = true)
#  |    |-- ManufacturerID: string (nullable = true)
#  |    |-- SupplierID: string (nullable = true)
#  |    |-- LTV: double (nullable = true)
#  |    |-- SEX: string (nullable = true)
#  |    |-- AGE: integer (nullable = true)
#  |    |-- MonthlyIncome: double (nullable = true)
#  |    |-- City: string (nullable = true)
#  |    |-- State: string (nullable = true)
#  |    |-- ZiPCODE: integer (nullable = true)
#  |    |-- Top-up Month: string (nullable = true)
#  |    |-- ts: timestamp (nullable = true)

# %%
# fetching nested values
df_cust_formatted = df_cust.select(
                    F.col("unnested_value.ID").alias("ID"),
                    F.col("unnested_value.Frequency").alias("Frequency"),
                    F.col("unnested_value.InstlmentMode").alias("InstlmentMode"),
                    F.col("unnested_value.LoanStatus").alias("LoanStatus"),
                    F.col("unnested_value.PaymentMode").alias("PaymentMode"),
                    F.col("unnested_value.BranchID").alias("BranchID"),
                    F.col("unnested_value.Area").alias("Area"),
                    F.col("unnested_value.Tenure").alias("Tenure"),
                    F.col("unnested_value.AssetCost").alias("AssetCost"),
                    F.col("unnested_value.AmountFinance").alias("AmountFinance"),
                    F.col("unnested_value.DisbursalAmount").alias("DisbursalAmount"),
                    F.col("unnested_value.EMI").alias("EMI"),
                    F.col("unnested_value.DisbursalDate").alias("DisbursalDate"),
                    F.col("unnested_value.MaturityDAte").alias("MaturityDAte"),
                    F.col("unnested_value.AuthDate").alias("AuthDate"),
                    F.col("unnested_value.AssetID").alias("AssetID"),
                    F.col("unnested_value.ManufacturerID").alias("ManufacturerID"),
                    F.col("unnested_value.SupplierID").alias("SupplierID"),
                    F.col("unnested_value.LTV").alias("LTV"),
                    F.col("unnested_value.SEX").alias("SEX"),
                    F.col("unnested_value.AGE").alias("AGE"),
                    F.col("unnested_value.MonthlyIncome").alias("MonthlyIncome"),
                    F.col("unnested_value.City").alias("City"),
                    F.col("unnested_value.State").alias("State"),
                    F.col("unnested_value.ZiPCODE").alias("ZiPCODE"),
                    F.col("unnested_value.Top-up Month").alias("Top-up Month"),
                    F.col("unnested_value.ts").alias("ts")
                )

# %%
# formated dataframe
df_cust_formatted.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- Frequency: string (nullable = true)
#  |-- InstlmentMode: string (nullable = true)
#  |-- LoanStatus: string (nullable = true)
#  |-- PaymentMode: string (nullable = true)
#  |-- BranchID: string (nullable = true)
#  |-- Area: string (nullable = true)
#  |-- Tenure: integer (nullable = true)
#  |-- AssetCost: integer (nullable = true)
#  |-- AmountFinance: double (nullable = true)
#  |-- DisbursalAmount: double (nullable = true)
#  |-- EMI: double (nullable = true)
#  |-- DisbursalDate: string (nullable = true)
#  |-- MaturityDAte: string (nullable = true)
#  |-- AuthDate: string (nullable = true)
#  |-- AssetID: string (nullable = true)
#  |-- ManufacturerID: string (nullable = true)
#  |-- SupplierID: string (nullable = true)
#  |-- LTV: double (nullable = true)
#  |-- SEX: string (nullable = true)
#  |-- AGE: integer (nullable = true)
#  |-- MonthlyIncome: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZiPCODE: integer (nullable = true)
#  |-- Top-up Month: string (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %%
# query_cust_sink = df_cust_formatted.writeStream.outputMode("append").format("console").trigger(processingTime='10 seconds').start()

# %%
df_bur.printSchema()
# Out:
# root
#  |-- unnested_value: struct (nullable = true)
#  |    |-- ID: integer (nullable = true)
#  |    |-- SELF-INDICATOR: string (nullable = true)
#  |    |-- MATCH-TYPE: string (nullable = true)
#  |    |-- ACCT-TYPE: string (nullable = true)
#  |    |-- CONTRIBUTOR-TYPE: string (nullable = true)
#  |    |-- DATE-REPORTED: string (nullable = true)
#  |    |-- OWNERSHIP-IND: string (nullable = true)
#  |    |-- ACCOUNT-STATUS: string (nullable = true)
#  |    |-- DISBURSED-DT: string (nullable = true)
#  |    |-- CLOSE-DT: string (nullable = true)
#  |    |-- LAST-PAYMENT-DATE: string (nullable = true)
#  |    |-- CREDIT-LIMIT/SANC AMT: string (nullable = true)
#  |    |-- DISBURSED-AMT/HIGH CREDIT: string (nullable = true)
#  |    |-- INSTALLMENT-AMT: string (nullable = true)
#  |    |-- CURRENT-BAL: string (nullable = true)
#  |    |-- INSTALLMENT-FREQUENCY: string (nullable = true)
#  |    |-- OVERDUE-AMT: string (nullable = true)
#  |    |-- WRITE-OFF-AMT: integer (nullable = true)
#  |    |-- ASSET_CLASS: string (nullable = true)
#  |    |-- REPORTED DATE - HIST: string (nullable = true)
#  |    |-- DPD - HIST: string (nullable = true)
#  |    |-- CUR BAL - HIST: string (nullable = true)
#  |    |-- AMT OVERDUE - HIST: string (nullable = true)
#  |    |-- AMT PAID - HIST: string (nullable = true)
#  |    |-- TENURE: integer (nullable = true)
#  |    |-- ts: timestamp (nullable = true)

# %%
# fetching nested values
df_bur_formatted = df_bur.select(
                    F.col("unnested_value.ID").alias("ID"),
                    F.col("unnested_value.SELF-INDICATOR").alias("SELF-INDICATOR"),
                    F.col("unnested_value.MATCH-TYPE").alias("MATCH-TYPE"),
                    F.col("unnested_value.ACCT-TYPE").alias("ACCT-TYPE"),
                    F.col("unnested_value.CONTRIBUTOR-TYPE").alias("CONTRIBUTOR-TYPE"),
                    F.col("unnested_value.DATE-REPORTED").alias("DATE-REPORTED"),
                    F.col("unnested_value.OWNERSHIP-IND").alias("OWNERSHIP-IND"),
                    F.col("unnested_value.ACCOUNT-STATUS").alias("ACCOUNT-STATUS"),
                    F.col("unnested_value.DISBURSED-DT").alias("DISBURSED-DT"),
                    F.col("unnested_value.CLOSE-DT").alias("CLOSE-DT"),
                    F.col("unnested_value.LAST-PAYMENT-DATE").alias("LAST-PAYMENT-DATE"),
                    F.col("unnested_value.CREDIT-LIMIT/SANC AMT").alias("CREDIT-LIMIT/SANC AMT"),
    
                    F.col("unnested_value.DISBURSED-AMT/HIGH CREDIT").alias("DISBURSED-AMT/HIGH CREDIT"),
                    F.col("unnested_value.INSTALLMENT-AMT").alias("INSTALLMENT-AMT"),
                    F.col("unnested_value.CURRENT-BAL").alias("CURRENT-BAL"),
                    F.col("unnested_value.INSTALLMENT-FREQUENCY").alias("INSTALLMENT-FREQUENCY"),
                    F.col("unnested_value.OVERDUE-AMT").alias("OVERDUE-AMT"),
                    F.col("unnested_value.WRITE-OFF-AMT").alias("WRITE-OFF-AMT"),
                    F.col("unnested_value.ASSET_CLASS").alias("ASSET_CLASS"),
                    F.col("unnested_value.REPORTED DATE - HIST").alias("REPORTED DATE - HIST"),
                    F.col("unnested_value.DPD - HIST").alias("DPD - HIST"),
                    F.col("unnested_value.CUR BAL - HIST").alias("CUR BAL - HIST"),
                    F.col("unnested_value.AMT OVERDUE - HIST").alias("AMT OVERDUE - HIST"),
                    F.col("unnested_value.AMT PAID - HIST").alias("AMT PAID - HIST"),
                    F.col("unnested_value.TENURE").alias("TENURE"),
                    F.col("unnested_value.ts").alias("ts")
                )

# %%
df_bur_formatted.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- SELF-INDICATOR: string (nullable = true)
#  |-- MATCH-TYPE: string (nullable = true)
#  |-- ACCT-TYPE: string (nullable = true)
#  |-- CONTRIBUTOR-TYPE: string (nullable = true)
#  |-- DATE-REPORTED: string (nullable = true)
#  |-- OWNERSHIP-IND: string (nullable = true)
#  |-- ACCOUNT-STATUS: string (nullable = true)
#  |-- DISBURSED-DT: string (nullable = true)
#  |-- CLOSE-DT: string (nullable = true)
#  |-- LAST-PAYMENT-DATE: string (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT: string (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT: string (nullable = true)
#  |-- INSTALLMENT-AMT: string (nullable = true)
#  |-- CURRENT-BAL: string (nullable = true)
#  |-- INSTALLMENT-FREQUENCY: string (nullable = true)
#  |-- OVERDUE-AMT: string (nullable = true)
#  |-- WRITE-OFF-AMT: integer (nullable = true)
#  |-- ASSET_CLASS: string (nullable = true)
#  |-- REPORTED DATE - HIST: string (nullable = true)
#  |-- DPD - HIST: string (nullable = true)
#  |-- CUR BAL - HIST: string (nullable = true)
#  |-- AMT OVERDUE - HIST: string (nullable = true)
#  |-- AMT PAID - HIST: string (nullable = true)
#  |-- TENURE: integer (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %%
# making watermark of ts to ensure we don't get data after 5 seconds
df_bur_formatted_watermark = df_bur_formatted.withWatermark("ts","5 seconds")
df_cust_formatted_watermark = df_cust_formatted.withWatermark("ts","5 seconds")

# %% [markdown]
# #### Group the bureau stream based on ID with 30 seconds window duration, similar to assignment 2A(same rule for sum and dist).
# - Transform the “SELF-INDICATOR” column’s values. If the value is true, then convert to 1, if the value is false, then convert to 0.
# - sum the rows for numeric type columns, count distinct values for other columns with other data types, and rename them with the postfix like '_sum' or '_dist'. (For example, we did the sum function based on the 'HIGH CREDIT', and the new column’s name will be 'HIGH CREDIT_sum').

# %%
# assinging 0 and 1 to top-up values
from pyspark.sql.functions import when
df_bur_update = df_bur_formatted_watermark \
                            .withColumn("SELF-INDICATOR", when(df_bur_formatted_watermark["SELF-INDICATOR"] == "TRUE",1) \
                            .otherwise(0))

# %%
df_bur_update.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- SELF-INDICATOR: integer (nullable = false)
#  |-- MATCH-TYPE: string (nullable = true)
#  |-- ACCT-TYPE: string (nullable = true)
#  |-- CONTRIBUTOR-TYPE: string (nullable = true)
#  |-- DATE-REPORTED: string (nullable = true)
#  |-- OWNERSHIP-IND: string (nullable = true)
#  |-- ACCOUNT-STATUS: string (nullable = true)
#  |-- DISBURSED-DT: string (nullable = true)
#  |-- CLOSE-DT: string (nullable = true)
#  |-- LAST-PAYMENT-DATE: string (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT: string (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT: string (nullable = true)
#  |-- INSTALLMENT-AMT: string (nullable = true)
#  |-- CURRENT-BAL: string (nullable = true)
#  |-- INSTALLMENT-FREQUENCY: string (nullable = true)
#  |-- OVERDUE-AMT: string (nullable = true)
#  |-- WRITE-OFF-AMT: integer (nullable = true)
#  |-- ASSET_CLASS: string (nullable = true)
#  |-- REPORTED DATE - HIST: string (nullable = true)
#  |-- DPD - HIST: string (nullable = true)
#  |-- CUR BAL - HIST: string (nullable = true)
#  |-- AMT OVERDUE - HIST: string (nullable = true)
#  |-- AMT PAID - HIST: string (nullable = true)
#  |-- TENURE: integer (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %%
from pyspark.sql.functions import col, split
from pyspark.sql.types import IntegerType

from pyspark.sql.functions import regexp_replace

# removing ',' and casting to integer
df_bur_update = df_bur_update.withColumn("OVERDUE-AMT", regexp_replace('OVERDUE-AMT', ',', '').cast(IntegerType())) \
                            .withColumn("CURRENT-BAL", regexp_replace('CURRENT-BAL', ',', '').cast(IntegerType())) \
                            .withColumn("DISBURSED-AMT/HIGH CREDIT", regexp_replace('DISBURSED-AMT/HIGH CREDIT', ',', '').cast(IntegerType())) \
                            .withColumn("CREDIT-LIMIT/SANC AMT", regexp_replace('CREDIT-LIMIT/SANC AMT', ',', '').cast(IntegerType())) \
                            .withColumn("INSTALLMENT-AMT", regexp_replace('INSTALLMENT-AMT', ',', '')) \
                            .withColumn("INSTALLMENT-AMT", split(col("INSTALLMENT-AMT"), "/").getItem(0).cast(IntegerType()))

# %%
from pyspark.sql.types import IntegerType
# list to store column names based on type
numeric_col = []
other_col = []
for itr in df_bur_update.schema.fields:
    if (itr.name != "ID"):
        if (isinstance(itr.dataType, IntegerType)):
            numeric_col.append(itr.name)
        else:
            other_col.append(itr.name)
# sum and distinct
df_bur_formatted = df_bur_update.groupBy(F.window(df_bur_update.ts, "30 seconds"), "ID").agg(
    *[F.sum(num).alias(num + "_sum") for num in numeric_col],
    *[F.approx_count_distinct(othr).alias(othr + "_dist") for othr in other_col])

# %%
df_bur_formatted.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- ID: integer (nullable = true)
#  |-- SELF-INDICATOR_sum: long (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT_sum: long (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT_sum: long (nullable = true)
#  |-- INSTALLMENT-AMT_sum: long (nullable = true)
#  |-- CURRENT-BAL_sum: long (nullable = true)
#  |-- OVERDUE-AMT_sum: long (nullable = true)
#  |-- WRITE-OFF-AMT_sum: long (nullable = true)
#  |-- TENURE_sum: long (nullable = true)
#  |-- MATCH-TYPE_dist: long (nullable = false)
#  |-- ACCT-TYPE_dist: long (nullable = false)
#  |-- CONTRIBUTOR-TYPE_dist: long (nullable = false)
#  |-- DATE-REPORTED_dist: long (nullable = false)
#  |-- OWNERSHIP-IND_dist: long (nullable = false)
#  |-- ACCOUNT-STATUS_dist: long (nullable = false)
#  |-- DISBURSED-DT_dist: long (nullable = false)
#  |-- CLOSE-DT_dist: long (nullable = false)
#  |-- LAST-PAYMENT-DATE_dist: long (nullable = false)
#  |-- INSTALLMENT-FREQUENCY_dist: long (nullable = false)
#  |-- ASSET_CLASS_dist: long (nullable = false)
#  |-- REPORTED DATE - HIST_dist: long (nullable = false)
#  |-- DPD - HIST_dist: long (nullable = false)
#  |-- CUR BAL - HIST_dist: long (nullable = false)
#  |-- AMT OVERDUE - HIST_dist: long (nullable = false)
#  |-- AMT PAID - HIST_dist: long (nullable = false)
#  |-- ts_dist: long (nullable = false)

# %%
# printing to console
#query_cust_sink = df_cust_formatted.writeStream.outputMode("append").format("console").trigger(processingTime='10 seconds').start()

# %%
#query_bur_sink = df_bur_formatted.writeStream.outputMode("append").format("console").trigger(processingTime='10 seconds').start()

# %% [markdown]
# ### Create new columns named 'window_start' and 'window_end' which are the window’s start time and end time in 2.4. Then inner join the 2 streams based on 'ID', and only customer data received between the window time are accepted. For example, customer data ID '3' received at 10:00, and only when the window of corresponding bureau data contains 10:00(like window start: 9:59, end: 10:00), then this data is accepted.

# %%
# adding column
df_bur_formatted = df_bur_formatted.withColumn("window_start",F.col("window.start")) \
                                            .withColumn("window_end",F.col("window.end"))

# %%
df_bur_formatted.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- ID: integer (nullable = true)
#  |-- SELF-INDICATOR_sum: long (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT_sum: long (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT_sum: long (nullable = true)
#  |-- INSTALLMENT-AMT_sum: long (nullable = true)
#  |-- CURRENT-BAL_sum: long (nullable = true)
#  |-- OVERDUE-AMT_sum: long (nullable = true)
#  |-- WRITE-OFF-AMT_sum: long (nullable = true)
#  |-- TENURE_sum: long (nullable = true)
#  |-- MATCH-TYPE_dist: long (nullable = false)
#  |-- ACCT-TYPE_dist: long (nullable = false)
#  |-- CONTRIBUTOR-TYPE_dist: long (nullable = false)
#  |-- DATE-REPORTED_dist: long (nullable = false)
#  |-- OWNERSHIP-IND_dist: long (nullable = false)
#  |-- ACCOUNT-STATUS_dist: long (nullable = false)
#  |-- DISBURSED-DT_dist: long (nullable = false)
#  |-- CLOSE-DT_dist: long (nullable = false)
#  |-- LAST-PAYMENT-DATE_dist: long (nullable = false)
#  |-- INSTALLMENT-FREQUENCY_dist: long (nullable = false)
#  |-- ASSET_CLASS_dist: long (nullable = false)
#  |-- REPORTED DATE - HIST_dist: long (nullable = false)
#  |-- DPD - HIST_dist: long (nullable = false)
#  |-- CUR BAL - HIST_dist: long (nullable = false)
#  |-- AMT OVERDUE - HIST_dist: long (nullable = false)
#  |-- AMT PAID - HIST_dist: long (nullable = false)
#  |-- ts_dist: long (nullable = false)
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)

# %%
# changing column name to avoid ambiguity
df_bur_New = df_bur_formatted.withColumnRenamed("ID","burID")

# %%
from pyspark.sql.functions import expr
# inner join between two data stream
join_data = df_bur_New.join(
  df_cust_formatted,
  expr("""
    ID == burID AND
    ts >= window_start AND
    ts <= window_end
    """),
  "inner"                 
)

# %%
join_data.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- burID: integer (nullable = true)
#  |-- SELF-INDICATOR_sum: long (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT_sum: long (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT_sum: long (nullable = true)
#  |-- INSTALLMENT-AMT_sum: long (nullable = true)
#  |-- CURRENT-BAL_sum: long (nullable = true)
#  |-- OVERDUE-AMT_sum: long (nullable = true)
#  |-- WRITE-OFF-AMT_sum: long (nullable = true)
#  |-- TENURE_sum: long (nullable = true)
#  |-- MATCH-TYPE_dist: long (nullable = false)
#  |-- ACCT-TYPE_dist: long (nullable = false)
#  |-- CONTRIBUTOR-TYPE_dist: long (nullable = false)
#  |-- DATE-REPORTED_dist: long (nullable = false)
#  |-- OWNERSHIP-IND_dist: long (nullable = false)
#  |-- ACCOUNT-STATUS_dist: long (nullable = false)
#  |-- DISBURSED-DT_dist: long (nullable = false)
#  |-- CLOSE-DT_dist: long (nullable = false)
#  |-- LAST-PAYMENT-DATE_dist: long (nullable = false)
#  |-- INSTALLMENT-FREQUENCY_dist: long (nullable = false)
#  |-- ASSET_CLASS_dist: long (nullable = false)
#  |-- REPORTED DATE - HIST_dist: long (nullable = false)
#  |-- DPD - HIST_dist: long (nullable = false)
#  |-- CUR BAL - HIST_dist: long (nullable = false)
#  |-- AMT OVERDUE - HIST_dist: long (nullable = false)
#  |-- AMT PAID - HIST_dist: long (nullable = false)
#  |-- ts_dist: long (nullable = false)
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)
#  |-- ID: integer (nullable = true)
#  |-- Frequency: string (nullable = true)
#  |-- InstlmentMode: string (nullable = true)
#  |-- LoanStatus: string (nullable = true)
#  |-- PaymentMode: string (nullable = true)
#  |-- BranchID: string (nullable = true)
#  |-- Area: string (nullable = true)
#  |-- Tenure: integer (nullable = true)
#  |-- AssetCost: integer (nullable = true)
#  |-- AmountFinance: double (nullable = true)
#  |-- DisbursalAmount: double (nullable = true)
#  |-- EMI: double (nullable = true)
#  |-- DisbursalDate: string (nullable = true)
#  |-- MaturityDAte: string (nullable = true)
#  |-- AuthDate: string (nullable = true)
#  |-- AssetID: string (nullable = true)
#  |-- ManufacturerID: string (nullable = true)
#  |-- SupplierID: string (nullable = true)
#  |-- LTV: double (nullable = true)
#  |-- SEX: string (nullable = true)
#  |-- AGE: integer (nullable = true)
#  |-- MonthlyIncome: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZiPCODE: integer (nullable = true)
#  |-- Top-up Month: string (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %% [markdown]
# #### Persist the above result in parquet format.(When you save the data to parquet format,you need to rename “Top-up Month” to “Top-up_Month” first. And only keep these columns “ID”, “window_start”, “window_end”, “ts”, “Top-up_Month”) Renaming “Top-up Month” only happen in this question

# %%
# changing column name
parquet_df = join_data.withColumnRenamed("Top-up Month","Top-up_Month")

# %%
parquet_df.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- burID: integer (nullable = true)
#  |-- SELF-INDICATOR_sum: long (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT_sum: long (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT_sum: long (nullable = true)
#  |-- INSTALLMENT-AMT_sum: long (nullable = true)
#  |-- CURRENT-BAL_sum: long (nullable = true)
#  |-- OVERDUE-AMT_sum: long (nullable = true)
#  |-- WRITE-OFF-AMT_sum: long (nullable = true)
#  |-- TENURE_sum: long (nullable = true)
#  |-- MATCH-TYPE_dist: long (nullable = false)
#  |-- ACCT-TYPE_dist: long (nullable = false)
#  |-- CONTRIBUTOR-TYPE_dist: long (nullable = false)
#  |-- DATE-REPORTED_dist: long (nullable = false)
#  |-- OWNERSHIP-IND_dist: long (nullable = false)
#  |-- ACCOUNT-STATUS_dist: long (nullable = false)
#  |-- DISBURSED-DT_dist: long (nullable = false)
#  |-- CLOSE-DT_dist: long (nullable = false)
#  |-- LAST-PAYMENT-DATE_dist: long (nullable = false)
#  |-- INSTALLMENT-FREQUENCY_dist: long (nullable = false)
#  |-- ASSET_CLASS_dist: long (nullable = false)
#  |-- REPORTED DATE - HIST_dist: long (nullable = false)
#  |-- DPD - HIST_dist: long (nullable = false)
#  |-- CUR BAL - HIST_dist: long (nullable = false)
#  |-- AMT OVERDUE - HIST_dist: long (nullable = false)
#  |-- AMT PAID - HIST_dist: long (nullable = false)
#  |-- ts_dist: long (nullable = false)
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)
#  |-- ID: integer (nullable = true)
#  |-- Frequency: string (nullable = true)
#  |-- InstlmentMode: string (nullable = true)
#  |-- LoanStatus: string (nullable = true)
#  |-- PaymentMode: string (nullable = true)
#  |-- BranchID: string (nullable = true)
#  |-- Area: string (nullable = true)
#  |-- Tenure: integer (nullable = true)
#  |-- AssetCost: integer (nullable = true)
#  |-- AmountFinance: double (nullable = true)
#  |-- DisbursalAmount: double (nullable = true)
#  |-- EMI: double (nullable = true)
#  |-- DisbursalDate: string (nullable = true)
#  |-- MaturityDAte: string (nullable = true)
#  |-- AuthDate: string (nullable = true)
#  |-- AssetID: string (nullable = true)
#  |-- ManufacturerID: string (nullable = true)
#  |-- SupplierID: string (nullable = true)
#  |-- LTV: double (nullable = true)
#  |-- SEX: string (nullable = true)
#  |-- AGE: integer (nullable = true)
#  |-- MonthlyIncome: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZiPCODE: integer (nullable = true)
#  |-- Top-up_Month: string (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %%
parquet_df = parquet_df.select("ID","window_start", "window_end", "ts")

# %%
parquet_df.printSchema()
# Out:
# root
#  |-- ID: integer (nullable = true)
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)
#  |-- ts: timestamp (nullable = true)

# %%
# Write into parquet files
query_file_sink = parquet_df.writeStream.format("parquet")\
        .outputMode("append")\
        .option("path", "parquet/performance_df")\
        .option("checkpointLocation", "parquet/performance_df/checkpoint")\
        .start()
# Out:
# 22/10/23 05:48:54 WARN UnsupportedOperationChecker: Detected pattern of possible 'correctness' issue due to global watermark. The query contains stateful operation which can emit rows older than the current watermark plus allowed late record delay, which are "late rows" in downstream stateful operations and these rows can be discarded. Please refer the programming guide doc for more details.;
# Project [ID#52, window_start#4041, window_end#4071, ts#78]
# +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 32 more fields]
#    +- Join Inner, (((ID#52 = burID#4102) AND (ts#78 >= window_start#4041)) AND (ts#78 <= window_end#4071))
#       :- Project [window#400-T5000ms, ID#133 AS burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 5 more fields]
#       :  +- Project [window#400-T5000ms, ID#133, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 5 more fields]
#       :     +- Project [window#400-T5000ms, ID#133, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 4 more fields]
#       :        +- Aggregate [window#4013-T5000ms, ID#133], [window#4013-T5000ms AS window#400-T5000ms, ID#133, sum(cast(SELF-INDICATOR#211 as bigint)) AS SELF-INDICATOR_sum#428L, sum(cast(CREDIT-LIMIT/SANC AMT#319 as bigint)) AS CREDIT-LIMIT/SANC AMT_sum#430L, sum(cast(DISBURSED-AMT/HIGH CREDIT#292 as bigint)) AS DISBURSED-AMT/HIGH CREDIT_sum#432L, sum(cast(INSTALLMENT-AMT#373 as bigint)) AS INSTALLMENT-AMT_sum#434L, sum(cast(CURRENT-BAL#265 as bigint)) AS CURRENT-BAL_sum#436L, sum(cast(OVERDUE-AMT#238 as bigint)) AS OVERDUE-AMT_sum#438L, sum(cast(WRITE-OFF-AMT#150 as bigint)) AS WRITE-OFF-AMT_sum#440L, sum(cast(TENURE#157 as bigint)) AS TENURE_sum#442L, approx_count_distinct(MATCH-TYPE#135, 0.05, 0, 0) AS MATCH-TYPE_dist#548L, approx_count_distinct(ACCT-TYPE#136, 0.05, 0, 0) AS ACCT-TYPE_dist#654L, approx_count_distinct(CONTRIBUTOR-TYPE#137, 0.05, 0, 0) AS CONTRIBUTOR-TYPE_dist#760L, approx_count_distinct(DATE-REPORTED#138, 0.05, 0, 0) AS DATE-REPORTED_dist#866L, approx_count_distinct(OWNERSHIP-IND#139, 0.05, 0, 0) AS OWNERSHIP-IND_dist#972L, approx_count_distinct(ACCOUNT-STATUS#140, 0.05, 0, 0) AS ACCOUNT-STATUS_dist#1078L, approx_count_distinct(DISBURSED-DT#141, 0.05, 0, 0) AS DISBURSED-DT_dist#1184L, approx_count_distinct(CLOSE-DT#142, 0.05, 0, 0) AS CLOSE-DT_dist#1290L, approx_count_distinct(LAST-PAYMENT-DATE#143, 0.05, 0, 0) AS LAST-PAYMENT-DATE_dist#1396L, approx_count_distinct(INSTALLMENT-FREQUENCY#148, 0.05, 0, 0) AS INSTALLMENT-FREQUENCY_dist#1502L, approx_count_distinct(ASSET_CLASS#151, 0.05, 0, 0) AS ASSET_CLASS_dist#1608L, approx_count_distinct(REPORTED DATE - HIST#152, 0.05, 0, 0) AS REPORTED DATE - HIST_dist#1714L, approx_count_distinct(DPD - HIST#153, 0.05, 0, 0) AS DPD - HIST_dist#1820L, approx_count_distinct(CUR BAL - HIST#154, 0.05, 0, 0) AS CUR BAL - HIST_dist#1926L, ... 3 more fields]
#       :           +- Filter isnotnull(ts#158-T5000ms)
#       :              +- Project [named_struct(start, precisetimestampconversion(((((CASE WHEN (cast(CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) as double) = (cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) THEN (CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) + cast(1 as bigint)) ELSE CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) END + cast(0 as bigint)) - cast(1 as bigint)) * 30000000) + 0), LongType, TimestampType), end, precisetimestampconversion((((((CASE WHEN (cast(CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) as double) = (cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) THEN (CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) + cast(1 as bigint)) ELSE CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) END + cast(0 as bigint)) - cast(1 as bigint)) * 30000000) + 0) + 30000000), LongType, TimestampType)) AS window#4013-T5000ms, ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#373, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, ... 3 more fields]
#       :                 +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, cast(split(INSTALLMENT-AMT#346, /, -1)[0] as int) AS INSTALLMENT-AMT#373, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                    +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, regexp_replace(INSTALLMENT-AMT#146, ,, ) AS INSTALLMENT-AMT#346, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                       +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, cast(regexp_replace(CREDIT-LIMIT/SANC AMT#144, ,, ) as int) AS CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#146, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                          +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, cast(regexp_replace(DISBURSED-AMT/HIGH CREDIT#145, ,, ) as int) AS DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#146, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                             +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, cast(regexp_replace(CURRENT-BAL#147, ,, ) as int) AS CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                                +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, CURRENT-BAL#147, INSTALLMENT-FREQUENCY#148, cast(regexp_replace(OVERDUE-AMT#149, ,, ) as int) AS OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                                   +- Project [ID#133, CASE WHEN (SELF-INDICATOR#134 = TRUE) THEN 1 ELSE 0 END AS SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, CURRENT-BAL#147, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#149, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#       :                                      +- EventTimeWatermark ts#158: timestamp, 5 seconds
#       :                                         +- Project [unnested_value#50.ID AS ID#133, unnested_value#50.SELF-INDICATOR AS SELF-INDICATOR#134, unnested_value#50.MATCH-TYPE AS MATCH-TYPE#135, unnested_value#50.ACCT-TYPE AS ACCT-TYPE#136, unnested_value#50.CONTRIBUTOR-TYPE AS CONTRIBUTOR-TYPE#137, unnested_value#50.DATE-REPORTED AS DATE-REPORTED#138, unnested_value#50.OWNERSHIP-IND AS OWNERSHIP-IND#139, unnested_value#50.ACCOUNT-STATUS AS ACCOUNT-STATUS#140, unnested_value#50.DISBURSED-DT AS DISBURSED-DT#141, unnested_value#50.CLOSE-DT AS CLOSE-DT#142, unnested_value#50.LAST-PAYMENT-DATE AS LAST-PAYMENT-DATE#143, unnested_value#50.CREDIT-LIMIT/SANC AMT AS CREDIT-LIMIT/SANC AMT#144, unnested_value#50.DISBURSED-AMT/HIGH CREDIT AS DISBURSED-AMT/HIGH CREDIT#145, unnested_value#50.INSTALLMENT-AMT AS INSTALLMENT-AMT#146, unnested_value#50.CURRENT-BAL AS CURRENT-BAL#147, unnested_value#50.INSTALLMENT-FREQUENCY AS INSTALLMENT-FREQUENCY#148, unnested_value#50.OVERDUE-AMT AS OVERDUE-AMT#149, unnested_value#50.WRITE-OFF-AMT AS WRITE-OFF-AMT#150, unnested_value#50.ASSET_CLASS AS ASSET_CLASS#151, unnested_value#50.REPORTED DATE - HIST AS REPORTED DATE - HIST#152, unnested_value#50.DPD - HIST AS DPD - HIST#153, unnested_value#50.CUR BAL - HIST AS CUR BAL - HIST#154, unnested_value#50.AMT OVERDUE - HIST AS AMT OVERDUE - HIST#155, unnested_value#50.AMT PAID - HIST AS AMT PAID - HIST#156, ... 2 more fields]
#       :                                            +- Project [unnested_value#50]
#       :                                               +- Generate explode(parsed_value#44), false, [unnested_value#50]
#       :                                                  +- Project [from_json(ArrayType(StructType(StructField(ID,IntegerType,true), StructField(SELF-INDICATOR,StringType,true), StructField(MATCH-TYPE,StringType,true), StructField(ACCT-TYPE,StringType,true), StructField(CONTRIBUTOR-TYPE,StringType,true), StructField(DATE-REPORTED,StringType,true), StructField(OWNERSHIP-IND,StringType,true), StructField(ACCOUNT-STATUS,StringType,true), StructField(DISBURSED-DT,StringType,true), StructField(CLOSE-DT,StringType,true), StructField(LAST-PAYMENT-DATE,StringType,true), StructField(CREDIT-LIMIT/SANC AMT,StringType,true), StructField(DISBURSED-AMT/HIGH CREDIT,StringType,true), StructField(INSTALLMENT-AMT,StringType,true), StructField(CURRENT-BAL,StringType,true), StructField(INSTALLMENT-FREQUENCY,StringType,true), StructField(OVERDUE-AMT,StringType,true), StructField(WRITE-OFF-AMT,IntegerType,true), StructField(ASSET_CLASS,StringType,true), StructField(REPORTED DATE - HIST,StringType,true), StructField(DPD - HIST,StringType,true), StructField(CUR BAL - HIST,StringType,true), StructField(AMT OVERDUE - HIST,StringType,true), StructField(AMT PAID - HIST,StringType,true), StructField(TENURE,IntegerType,true), StructField(ts,TimestampType,true)),true), cast(value#29 as string), Some(UTC)) AS parsed_value#44]
#       :                                                     +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@791247c9, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@2b3dc35f, org.apache.spark.sql.util.CaseInsensitiveStringMap@d7a373e3, [key#28, value#29, topic#30, partition#31, offset#32L, timestamp#33, timestampType#34], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@17ec9b9c,kafka,List(),None,List(),None,Map(subscribe -> bureau_data, kafka.bootstrap.servers -> localhost:9092),None), kafka, [key#21, value#22, topic#23, partition#24, offset#25L, timestamp#26, timestampType#27]
#       +- Project [unnested_value#47.ID AS ID#52, unnested_value#47.Frequency AS Frequency#53, unnested_value#47.InstlmentMode AS InstlmentMode#54, unnested_value#47.LoanStatus AS LoanStatus#55, unnested_value#47.PaymentMode AS PaymentMode#56, unnested_value#47.BranchID AS BranchID#57, unnested_value#47.Area AS Area#58, unnested_value#47.Tenure AS Tenure#59, unnested_value#47.AssetCost AS AssetCost#60, unnested_value#47.AmountFinance AS AmountFinance#61, unnested_value#47.DisbursalAmount AS DisbursalAmount#62, unnested_value#47.EMI AS EMI#63, unnested_value#47.DisbursalDate AS DisbursalDate#64, unnested_value#47.MaturityDAte AS MaturityDAte#65, unnested_value#47.AuthDate AS AuthDate#66, unnested_value#47.AssetID AS AssetID#67, unnested_value#47.ManufacturerID AS ManufacturerID#68, unnested_value#47.SupplierID AS SupplierID#69, unnested_value#47.LTV AS LTV#70, unnested_value#47.SEX AS SEX#71, unnested_value#47.AGE AS AGE#72, unnested_value#47.MonthlyIncome AS MonthlyIncome#73, unnested_value#47.City AS City#74, unnested_value#47.State AS State#75, ... 3 more fields]
#          +- Project [unnested_value#47]
#             +- Generate explode(parsed_value#42), false, [unnested_value#47]
#                +- Project [from_json(ArrayType(StructType(StructField(ID,IntegerType,true), StructField(Frequency,StringType,true), StructField(InstlmentMode,StringType,true), StructField(LoanStatus,StringType,true), StructField(PaymentMode,StringType,true), StructField(BranchID,StringType,true), StructField(Area,StringType,true), StructField(Tenure,IntegerType,true), StructField(AssetCost,IntegerType,true), StructField(AmountFinance,DoubleType,true), StructField(DisbursalAmount,DoubleType,true), StructField(EMI,DoubleType,true), StructField(DisbursalDate,StringType,true), StructField(MaturityDAte,StringType,true), StructField(AuthDate,StringType,true), StructField(AssetID,StringType,true), StructField(ManufacturerID,StringType,true), StructField(SupplierID,StringType,true), StructField(LTV,DoubleType,true), StructField(SEX,StringType,true), StructField(AGE,IntegerType,true), StructField(MonthlyIncome,DoubleType,true), StructField(City,StringType,true), StructField(State,StringType,true), StructField(ZiPCODE,IntegerType,true), StructField(Top-up Month,StringType,true), StructField(ts,TimestampType,true)),true), cast(value#8 as string), Some(UTC)) AS parsed_value#42]
#                   +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@1cae2096, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@1fc7ad21, org.apache.spark.sql.util.CaseInsensitiveStringMap@152a74ff, [key#7, value#8, topic#9, partition#10, offset#11L, timestamp#12, timestampType#13], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@17ec9b9c,kafka,List(),None,List(),None,Map(subscribe -> customer_data, kafka.bootstrap.servers -> localhost:9092),None), kafka, [key#0, value#1, topic#2, partition#3, offset#4L, timestamp#5, timestampType#6]

# %%
#Stop the file_sink query
query_file_sink.stop()

# %% [markdown]
# #### Load the machine learning models given and use the model to predict whether users will be joining the top-up service. Save the results in parquet format. (When you save the data to parquet format,you need to rename “Top-up Month” to “Top-up_Month” first. And only keep these columns “ID”, “window_start”, “window_end”, “ts”, “prediction”, “Top-up_Month”) Renaming “Top-up Month” will happen in this question as well

# %%
# read pickled model via pipeline api
from pyspark.ml.pipeline import PipelineModel

topup_ml_model = PipelineModel.load("topup_pipeline_model")
# handling null values
topup_ml_model.stages[-2].setHandleInvalid("keep")
# Out:
# VectorAssembler_ac48f700b95d

# %%
# predict
predictionsDF = topup_ml_model.transform(join_data)

# %%
# schema after prediction
predictionsDF.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- burID: integer (nullable = true)
#  |-- SELF-INDICATOR_sum: long (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT_sum: long (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT_sum: long (nullable = true)
#  |-- INSTALLMENT-AMT_sum: long (nullable = true)
#  |-- CURRENT-BAL_sum: long (nullable = true)
#  |-- OVERDUE-AMT_sum: long (nullable = true)
#  |-- WRITE-OFF-AMT_sum: long (nullable = true)
#  |-- TENURE_sum: long (nullable = true)
#  |-- MATCH-TYPE_dist: long (nullable = false)
#  |-- ACCT-TYPE_dist: long (nullable = false)
#  |-- CONTRIBUTOR-TYPE_dist: long (nullable = false)
#  |-- DATE-REPORTED_dist: long (nullable = false)
#  |-- OWNERSHIP-IND_dist: long (nullable = false)
#  |-- ACCOUNT-STATUS_dist: long (nullable = false)
#  |-- DISBURSED-DT_dist: long (nullable = false)
#  |-- CLOSE-DT_dist: long (nullable = false)
#  |-- LAST-PAYMENT-DATE_dist: long (nullable = false)
#  |-- INSTALLMENT-FREQUENCY_dist: long (nullable = false)
#  |-- ASSET_CLASS_dist: long (nullable = false)
#  |-- REPORTED DATE - HIST_dist: long (nullable = false)
#  |-- DPD - HIST_dist: long (nullable = false)
#  |-- CUR BAL - HIST_dist: long (nullable = false)
#  |-- AMT OVERDUE - HIST_dist: long (nullable = false)
#  |-- AMT PAID - HIST_dist: long (nullable = false)
#  |-- ts_dist: long (nullable = false)
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)
#  |-- ID: integer (nullable = true)
#  |-- Frequency: string (nullable = true)
#  |-- InstlmentMode: string (nullable = true)
#  |-- LoanStatus: string (nullable = true)
#  |-- PaymentMode: string (nullable = true)
#  |-- BranchID: string (nullable = true)
#  |-- Area: string (nullable = true)
#  |-- Tenure: integer (nullable = true)
#  |-- AssetCost: integer (nullable = true)
#  |-- AmountFinance: double (nullable = true)
#  |-- DisbursalAmount: double (nullable = true)
#  |-- EMI: double (nullable = true)
#  |-- DisbursalDate: string (nullable = true)
#  |-- MaturityDAte: string (nullable = true)
#  |-- AuthDate: string (nullable = true)
#  |-- AssetID: string (nullable = true)
#  |-- ManufacturerID: string (nullable = true)
#  |-- SupplierID: string (nullable = true)
#  |-- LTV: double (nullable = true)
#  |-- SEX: string (nullable = true)
#  |-- AGE: integer (nullable = true)
#  |-- MonthlyIncome: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZiPCODE: integer (nullable = true)
#  |-- Top-up Month: string (nullable = true)
#  |-- ts: timestamp (nullable = true)
#  |-- State_idx: double (nullable = false)
#  |-- City_idx: double (nullable = false)
#  |-- BranchID_idx: double (nullable = false)
#  |-- Area_idx: double (nullable = false)
#  |-- ManufacturerID_idx: double (nullable = false)
#  |-- LoanStatus_idx: double (nullable = false)
#  |-- Tenure_idx: double (nullable = false)
#  |-- City_vec: vector (nullable = true)
#  |-- State_vec: vector (nullable = true)
#  |-- Tenure_vec: vector (nullable = true)
#  |-- LoanStatus_vec: vector (nullable = true)
#  |-- Area_vec: vector (nullable = true)
#  |-- BranchID_vec: vector (nullable = true)
#  |-- ManufacturerID_vec: vector (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = false)

# %%
# renaming column
prediction_parquet = predictionsDF.withColumnRenamed("Top-up Month","Top-up_Month")

# %%
prediction_parquet.printSchema()
# Out:
# root
#  |-- window: struct (nullable = false)
#  |    |-- start: timestamp (nullable = true)
#  |    |-- end: timestamp (nullable = true)
#  |-- burID: integer (nullable = true)
#  |-- SELF-INDICATOR_sum: long (nullable = true)
#  |-- CREDIT-LIMIT/SANC AMT_sum: long (nullable = true)
#  |-- DISBURSED-AMT/HIGH CREDIT_sum: long (nullable = true)
#  |-- INSTALLMENT-AMT_sum: long (nullable = true)
#  |-- CURRENT-BAL_sum: long (nullable = true)
#  |-- OVERDUE-AMT_sum: long (nullable = true)
#  |-- WRITE-OFF-AMT_sum: long (nullable = true)
#  |-- TENURE_sum: long (nullable = true)
#  |-- MATCH-TYPE_dist: long (nullable = false)
#  |-- ACCT-TYPE_dist: long (nullable = false)
#  |-- CONTRIBUTOR-TYPE_dist: long (nullable = false)
#  |-- DATE-REPORTED_dist: long (nullable = false)
#  |-- OWNERSHIP-IND_dist: long (nullable = false)
#  |-- ACCOUNT-STATUS_dist: long (nullable = false)
#  |-- DISBURSED-DT_dist: long (nullable = false)
#  |-- CLOSE-DT_dist: long (nullable = false)
#  |-- LAST-PAYMENT-DATE_dist: long (nullable = false)
#  |-- INSTALLMENT-FREQUENCY_dist: long (nullable = false)
#  |-- ASSET_CLASS_dist: long (nullable = false)
#  |-- REPORTED DATE - HIST_dist: long (nullable = false)
#  |-- DPD - HIST_dist: long (nullable = false)
#  |-- CUR BAL - HIST_dist: long (nullable = false)
#  |-- AMT OVERDUE - HIST_dist: long (nullable = false)
#  |-- AMT PAID - HIST_dist: long (nullable = false)
#  |-- ts_dist: long (nullable = false)
#  |-- window_start: timestamp (nullable = true)
#  |-- window_end: timestamp (nullable = true)
#  |-- ID: integer (nullable = true)
#  |-- Frequency: string (nullable = true)
#  |-- InstlmentMode: string (nullable = true)
#  |-- LoanStatus: string (nullable = true)
#  |-- PaymentMode: string (nullable = true)
#  |-- BranchID: string (nullable = true)
#  |-- Area: string (nullable = true)
#  |-- Tenure: integer (nullable = true)
#  |-- AssetCost: integer (nullable = true)
#  |-- AmountFinance: double (nullable = true)
#  |-- DisbursalAmount: double (nullable = true)
#  |-- EMI: double (nullable = true)
#  |-- DisbursalDate: string (nullable = true)
#  |-- MaturityDAte: string (nullable = true)
#  |-- AuthDate: string (nullable = true)
#  |-- AssetID: string (nullable = true)
#  |-- ManufacturerID: string (nullable = true)
#  |-- SupplierID: string (nullable = true)
#  |-- LTV: double (nullable = true)
#  |-- SEX: string (nullable = true)
#  |-- AGE: integer (nullable = true)
#  |-- MonthlyIncome: double (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZiPCODE: integer (nullable = true)
#  |-- Top-up_Month: string (nullable = true)
#  |-- ts: timestamp (nullable = true)
#  |-- State_idx: double (nullable = false)
#  |-- City_idx: double (nullable = false)
#  |-- BranchID_idx: double (nullable = false)
#  |-- Area_idx: double (nullable = false)
#  |-- ManufacturerID_idx: double (nullable = false)
#  |-- LoanStatus_idx: double (nullable = false)
#  |-- Tenure_idx: double (nullable = false)
#  |-- City_vec: vector (nullable = true)
#  |-- State_vec: vector (nullable = true)
#  |-- Tenure_vec: vector (nullable = true)
#  |-- LoanStatus_vec: vector (nullable = true)
#  |-- Area_vec: vector (nullable = true)
#  |-- BranchID_vec: vector (nullable = true)
#  |-- ManufacturerID_vec: vector (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- rawPrediction: vector (nullable = true)
#  |-- probability: vector (nullable = true)
#  |-- prediction: double (nullable = false)

# %%
# selecting required columns
prediction_df = prediction_parquet.select("ID","window_start", 
                                  "window_end", "ts", 
                                  "prediction", "Top-up_Month")

# %%
# Write into parquet files
prediction_file_sink = predictionsDF.writeStream.format("parquet")\
        .outputMode("append")\
        .option("path", "parquet/prediction_df")\
        .option("checkpointLocation", "parquet/performance_df/checkpoint")\
        .start()
# Out:
# 22/10/23 05:49:02 WARN UnsupportedOperationChecker: Detected pattern of possible 'correctness' issue due to global watermark. The query contains stateful operation which can emit rows older than the current watermark plus allowed late record delay, which are "late rows" in downstream stateful operations and these rows can be discarded. Please refer the programming guide doc for more details.;
# Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 50 more fields]
# +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 49 more fields]
#    +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 48 more fields]
#       +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 47 more fields]
#          +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 46 more fields]
#             +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 39 more fields]
#                +- Join Inner, (((ID#52 = burID#4102) AND (ts#78 >= window_start#4041)) AND (ts#78 <= window_end#4071))
#                   :- Project [window#400-T5000ms, ID#133 AS burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 5 more fields]
#                   :  +- Project [window#400-T5000ms, ID#133, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 5 more fields]
#                   :     +- Project [window#400-T5000ms, ID#133, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 4 more fields]
#                   :        +- Aggregate [window#4013-T5000ms, ID#133], [window#4013-T5000ms AS window#400-T5000ms, ID#133, sum(cast(SELF-INDICATOR#211 as bigint)) AS SELF-INDICATOR_sum#428L, sum(cast(CREDIT-LIMIT/SANC AMT#319 as bigint)) AS CREDIT-LIMIT/SANC AMT_sum#430L, sum(cast(DISBURSED-AMT/HIGH CREDIT#292 as bigint)) AS DISBURSED-AMT/HIGH CREDIT_sum#432L, sum(cast(INSTALLMENT-AMT#373 as bigint)) AS INSTALLMENT-AMT_sum#434L, sum(cast(CURRENT-BAL#265 as bigint)) AS CURRENT-BAL_sum#436L, sum(cast(OVERDUE-AMT#238 as bigint)) AS OVERDUE-AMT_sum#438L, sum(cast(WRITE-OFF-AMT#150 as bigint)) AS WRITE-OFF-AMT_sum#440L, sum(cast(TENURE#157 as bigint)) AS TENURE_sum#442L, approx_count_distinct(MATCH-TYPE#135, 0.05, 0, 0) AS MATCH-TYPE_dist#548L, approx_count_distinct(ACCT-TYPE#136, 0.05, 0, 0) AS ACCT-TYPE_dist#654L, approx_count_distinct(CONTRIBUTOR-TYPE#137, 0.05, 0, 0) AS CONTRIBUTOR-TYPE_dist#760L, approx_count_distinct(DATE-REPORTED#138, 0.05, 0, 0) AS DATE-REPORTED_dist#866L, approx_count_distinct(OWNERSHIP-IND#139, 0.05, 0, 0) AS OWNERSHIP-IND_dist#972L, approx_count_distinct(ACCOUNT-STATUS#140, 0.05, 0, 0) AS ACCOUNT-STATUS_dist#1078L, approx_count_distinct(DISBURSED-DT#141, 0.05, 0, 0) AS DISBURSED-DT_dist#1184L, approx_count_distinct(CLOSE-DT#142, 0.05, 0, 0) AS CLOSE-DT_dist#1290L, approx_count_distinct(LAST-PAYMENT-DATE#143, 0.05, 0, 0) AS LAST-PAYMENT-DATE_dist#1396L, approx_count_distinct(INSTALLMENT-FREQUENCY#148, 0.05, 0, 0) AS INSTALLMENT-FREQUENCY_dist#1502L, approx_count_distinct(ASSET_CLASS#151, 0.05, 0, 0) AS ASSET_CLASS_dist#1608L, approx_count_distinct(REPORTED DATE - HIST#152, 0.05, 0, 0) AS REPORTED DATE - HIST_dist#1714L, approx_count_distinct(DPD - HIST#153, 0.05, 0, 0) AS DPD - HIST_dist#1820L, approx_count_distinct(CUR BAL - HIST#154, 0.05, 0, 0) AS CUR BAL - HIST_dist#1926L, ... 3 more fields]
#                   :           +- Filter isnotnull(ts#158-T5000ms)
#                   :              +- Project [named_struct(start, precisetimestampconversion(((((CASE WHEN (cast(CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) as double) = (cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) THEN (CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) + cast(1 as bigint)) ELSE CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) END + cast(0 as bigint)) - cast(1 as bigint)) * 30000000) + 0), LongType, TimestampType), end, precisetimestampconversion((((((CASE WHEN (cast(CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) as double) = (cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) THEN (CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) + cast(1 as bigint)) ELSE CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) END + cast(0 as bigint)) - cast(1 as bigint)) * 30000000) + 0) + 30000000), LongType, TimestampType)) AS window#4013-T5000ms, ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#373, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, ... 3 more fields]
#                   :                 +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, cast(split(INSTALLMENT-AMT#346, /, -1)[0] as int) AS INSTALLMENT-AMT#373, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                    +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, regexp_replace(INSTALLMENT-AMT#146, ,, ) AS INSTALLMENT-AMT#346, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                       +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, cast(regexp_replace(CREDIT-LIMIT/SANC AMT#144, ,, ) as int) AS CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#146, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                          +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, cast(regexp_replace(DISBURSED-AMT/HIGH CREDIT#145, ,, ) as int) AS DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#146, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                             +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, cast(regexp_replace(CURRENT-BAL#147, ,, ) as int) AS CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                                +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, CURRENT-BAL#147, INSTALLMENT-FREQUENCY#148, cast(regexp_replace(OVERDUE-AMT#149, ,, ) as int) AS OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                                   +- Project [ID#133, CASE WHEN (SELF-INDICATOR#134 = TRUE) THEN 1 ELSE 0 END AS SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, CURRENT-BAL#147, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#149, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                                      +- EventTimeWatermark ts#158: timestamp, 5 seconds
#                   :                                         +- Project [unnested_value#50.ID AS ID#133, unnested_value#50.SELF-INDICATOR AS SELF-INDICATOR#134, unnested_value#50.MATCH-TYPE AS MATCH-TYPE#135, unnested_value#50.ACCT-TYPE AS ACCT-TYPE#136, unnested_value#50.CONTRIBUTOR-TYPE AS CONTRIBUTOR-TYPE#137, unnested_value#50.DATE-REPORTED AS DATE-REPORTED#138, unnested_value#50.OWNERSHIP-IND AS OWNERSHIP-IND#139, unnested_value#50.ACCOUNT-STATUS AS ACCOUNT-STATUS#140, unnested_value#50.DISBURSED-DT AS DISBURSED-DT#141, unnested_value#50.CLOSE-DT AS CLOSE-DT#142, unnested_value#50.LAST-PAYMENT-DATE AS LAST-PAYMENT-DATE#143, unnested_value#50.CREDIT-LIMIT/SANC AMT AS CREDIT-LIMIT/SANC AMT#144, unnested_value#50.DISBURSED-AMT/HIGH CREDIT AS DISBURSED-AMT/HIGH CREDIT#145, unnested_value#50.INSTALLMENT-AMT AS INSTALLMENT-AMT#146, unnested_value#50.CURRENT-BAL AS CURRENT-BAL#147, unnested_value#50.INSTALLMENT-FREQUENCY AS INSTALLMENT-FREQUENCY#148, unnested_value#50.OVERDUE-AMT AS OVERDUE-AMT#149, unnested_value#50.WRITE-OFF-AMT AS WRITE-OFF-AMT#150, unnested_value#50.ASSET_CLASS AS ASSET_CLASS#151, unnested_value#50.REPORTED DATE - HIST AS REPORTED DATE - HIST#152, unnested_value#50.DPD - HIST AS DPD - HIST#153, unnested_value#50.CUR BAL - HIST AS CUR BAL - HIST#154, unnested_value#50.AMT OVERDUE - HIST AS AMT OVERDUE - HIST#155, unnested_value#50.AMT PAID - HIST AS AMT PAID - HIST#156, ... 2 more fields]
#                   :                                            +- Project [unnested_value#50]
#                   :                                               +- Generate explode(parsed_value#44), false, [unnested_value#50]
#                   :                                                  +- Project [from_json(ArrayType(StructType(StructField(ID,IntegerType,true), StructField(SELF-INDICATOR,StringType,true), StructField(MATCH-TYPE,StringType,true), StructField(ACCT-TYPE,StringType,true), StructField(CONTRIBUTOR-TYPE,StringType,true), StructField(DATE-REPORTED,StringType,true), StructField(OWNERSHIP-IND,StringType,true), StructField(ACCOUNT-STATUS,StringType,true), StructField(DISBURSED-DT,StringType,true), StructField(CLOSE-DT,StringType,true), StructField(LAST-PAYMENT-DATE,StringType,true), StructField(CREDIT-LIMIT/SANC AMT,StringType,true), StructField(DISBURSED-AMT/HIGH CREDIT,StringType,true), StructField(INSTALLMENT-AMT,StringType,true), StructField(CURRENT-BAL,StringType,true), StructField(INSTALLMENT-FREQUENCY,StringType,true), StructField(OVERDUE-AMT,StringType,true), StructField(WRITE-OFF-AMT,IntegerType,true), StructField(ASSET_CLASS,StringType,true), StructField(REPORTED DATE - HIST,StringType,true), StructField(DPD - HIST,StringType,true), StructField(CUR BAL - HIST,StringType,true), StructField(AMT OVERDUE - HIST,StringType,true), StructField(AMT PAID - HIST,StringType,true), StructField(TENURE,IntegerType,true), StructField(ts,TimestampType,true)),true), cast(value#29 as string), Some(UTC)) AS parsed_value#44]
#                   :                                                     +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@791247c9, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@2b3dc35f, org.apache.spark.sql.util.CaseInsensitiveStringMap@d7a373e3, [key#28, value#29, topic#30, partition#31, offset#32L, timestamp#33, timestampType#34], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@17ec9b9c,kafka,List(),None,List(),None,Map(subscribe -> bureau_data, kafka.bootstrap.servers -> localhost:9092),None), kafka, [key#21, value#22, topic#23, partition#24, offset#25L, timestamp#26, timestampType#27]
#                   +- Project [unnested_value#47.ID AS ID#52, unnested_value#47.Frequency AS Frequency#53, unnested_value#47.InstlmentMode AS InstlmentMode#54, unnested_value#47.LoanStatus AS LoanStatus#55, unnested_value#47.PaymentMode AS PaymentMode#56, unnested_value#47.BranchID AS BranchID#57, unnested_value#47.Area AS Area#58, unnested_value#47.Tenure AS Tenure#59, unnested_value#47.AssetCost AS AssetCost#60, unnested_value#47.AmountFinance AS AmountFinance#61, unnested_value#47.DisbursalAmount AS DisbursalAmount#62, unnested_value#47.EMI AS EMI#63, unnested_value#47.DisbursalDate AS DisbursalDate#64, unnested_value#47.MaturityDAte AS MaturityDAte#65, unnested_value#47.AuthDate AS AuthDate#66, unnested_value#47.AssetID AS AssetID#67, unnested_value#47.ManufacturerID AS ManufacturerID#68, unnested_value#47.SupplierID AS SupplierID#69, unnested_value#47.LTV AS LTV#70, unnested_value#47.SEX AS SEX#71, unnested_value#47.AGE AS AGE#72, unnested_value#47.MonthlyIncome AS MonthlyIncome#73, unnested_value#47.City AS City#74, unnested_value#47.State AS State#75, ... 3 more fields]
#                      +- Project [unnested_value#47]
#                         +- Generate explode(parsed_value#42), false, [unnested_value#47]
#                            +- Project [from_json(ArrayType(StructType(StructField(ID,IntegerType,true), StructField(Frequency,StringType,true), StructField(InstlmentMode,StringType,true), StructField(LoanStatus,StringType,true), StructField(PaymentMode,StringType,true), StructField(BranchID,StringType,true), StructField(Area,StringType,true), StructField(Tenure,IntegerType,true), StructField(AssetCost,IntegerType,true), StructField(AmountFinance,DoubleType,true), StructField(DisbursalAmount,DoubleType,true), StructField(EMI,DoubleType,true), StructField(DisbursalDate,StringType,true), StructField(MaturityDAte,StringType,true), StructField(AuthDate,StringType,true), StructField(AssetID,StringType,true), StructField(ManufacturerID,StringType,true), StructField(SupplierID,StringType,true), StructField(LTV,DoubleType,true), StructField(SEX,StringType,true), StructField(AGE,IntegerType,true), StructField(MonthlyIncome,DoubleType,true), StructField(City,StringType,true), StructField(State,StringType,true), StructField(ZiPCODE,IntegerType,true), StructField(Top-up Month,StringType,true), StructField(ts,TimestampType,true)),true), cast(value#8 as string), Some(UTC)) AS parsed_value#42]
#                               +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@1cae2096, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@1fc7ad21, org.apache.spark.sql.util.CaseInsensitiveStringMap@152a74ff, [key#7, value#8, topic#9, partition#10, offset#11L, timestamp#12, timestampType#13], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@17ec9b9c,kafka,List(),None,List(),None,Map(subscribe -> customer_data, kafka.bootstrap.servers -> localhost:9092),None), kafka, [key#0, value#1, topic#2, partition#3, offset#4L, timestamp#5, timestampType#6]

# %%
#Stop the file_sink query
query_file_sink.stop()

# %% [markdown]
# #### 8
# Only keep the customer predicted as our target customers (willing to join the top-up service). Normally, we should only keep “Top-up=1”. But due to the limited performance of our VM, if your process is extremely slow, you can abandon the filter and keep all of the data. Then for each batch, show the epoch id and count of the dataframe.
# If the dataframe is not empty, transform the data to the following key/value format, which key is 'window_end' column and the data are the numbers of top-up services customers in the different states(in JSON format). Then send it to Kafka with a proper topic. These data will be used for the real-time monitoring in task 3.

# %%
# Create function to show values received from input dataframe
# refered from chapter 8 (Structured Streaming) learning spark
from pyspark.sql.functions import *
def foreach_batch_function(df, epoch_id):
    if(df_empty.isEmpty()):
       print("data frame is empty")
        
    else:
        # filter prediction value
        filtered = df.filter(df.prediction == 1.0)
        
        #group by window_end and state then storing key and value data
        transform_df = filtered.groupBy("window_end", "State").count()\
                        .groupBy("window_end")\
                        .agg(collect_set(ArrayType(StructType(col('State'),col('count')))).alias("value"))\
                        .withColumnRenamed("window_end", "Key") \
                        .withColumn("value", to_json(col("value"))) 
    # sending data to kafka port
    transform_df.write\
            .format("kafka")\
            .option("kafka.bootstrap.servers", 'localhost:9092')\
            .option("topic", "top_up_customer")
        
    
    
        
    print(f"Epoch id:  {epoch_id} and count of the dataframe is {df.count()}")

# %%
# using foreachBatch to modify batch data
query1 = (
    predictionsDF.writeStream.outputMode("Append")
        .foreachBatch(foreach_batch_function)\
        .start()
)
# Out:
# 22/10/23 05:49:02 WARN StreamingQueryManager: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-dfa8362f-baaf-497d-a444-6f2609130a28. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 22/10/23 05:49:02 WARN UnsupportedOperationChecker: Detected pattern of possible 'correctness' issue due to global watermark. The query contains stateful operation which can emit rows older than the current watermark plus allowed late record delay, which are "late rows" in downstream stateful operations and these rows can be discarded. Please refer the programming guide doc for more details.;
# Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 50 more fields]
# +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 49 more fields]
#    +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 48 more fields]
#       +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 47 more fields]
#          +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 46 more fields]
#             +- Project [window#400-T5000ms, burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 39 more fields]
#                +- Join Inner, (((ID#52 = burID#4102) AND (ts#78 >= window_start#4041)) AND (ts#78 <= window_end#4071))
#                   :- Project [window#400-T5000ms, ID#133 AS burID#4102, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 5 more fields]
#                   :  +- Project [window#400-T5000ms, ID#133, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 5 more fields]
#                   :     +- Project [window#400-T5000ms, ID#133, SELF-INDICATOR_sum#428L, CREDIT-LIMIT/SANC AMT_sum#430L, DISBURSED-AMT/HIGH CREDIT_sum#432L, INSTALLMENT-AMT_sum#434L, CURRENT-BAL_sum#436L, OVERDUE-AMT_sum#438L, WRITE-OFF-AMT_sum#440L, TENURE_sum#442L, MATCH-TYPE_dist#548L, ACCT-TYPE_dist#654L, CONTRIBUTOR-TYPE_dist#760L, DATE-REPORTED_dist#866L, OWNERSHIP-IND_dist#972L, ACCOUNT-STATUS_dist#1078L, DISBURSED-DT_dist#1184L, CLOSE-DT_dist#1290L, LAST-PAYMENT-DATE_dist#1396L, INSTALLMENT-FREQUENCY_dist#1502L, ASSET_CLASS_dist#1608L, REPORTED DATE - HIST_dist#1714L, DPD - HIST_dist#1820L, CUR BAL - HIST_dist#1926L, ... 4 more fields]
#                   :        +- Aggregate [window#4013-T5000ms, ID#133], [window#4013-T5000ms AS window#400-T5000ms, ID#133, sum(cast(SELF-INDICATOR#211 as bigint)) AS SELF-INDICATOR_sum#428L, sum(cast(CREDIT-LIMIT/SANC AMT#319 as bigint)) AS CREDIT-LIMIT/SANC AMT_sum#430L, sum(cast(DISBURSED-AMT/HIGH CREDIT#292 as bigint)) AS DISBURSED-AMT/HIGH CREDIT_sum#432L, sum(cast(INSTALLMENT-AMT#373 as bigint)) AS INSTALLMENT-AMT_sum#434L, sum(cast(CURRENT-BAL#265 as bigint)) AS CURRENT-BAL_sum#436L, sum(cast(OVERDUE-AMT#238 as bigint)) AS OVERDUE-AMT_sum#438L, sum(cast(WRITE-OFF-AMT#150 as bigint)) AS WRITE-OFF-AMT_sum#440L, sum(cast(TENURE#157 as bigint)) AS TENURE_sum#442L, approx_count_distinct(MATCH-TYPE#135, 0.05, 0, 0) AS MATCH-TYPE_dist#548L, approx_count_distinct(ACCT-TYPE#136, 0.05, 0, 0) AS ACCT-TYPE_dist#654L, approx_count_distinct(CONTRIBUTOR-TYPE#137, 0.05, 0, 0) AS CONTRIBUTOR-TYPE_dist#760L, approx_count_distinct(DATE-REPORTED#138, 0.05, 0, 0) AS DATE-REPORTED_dist#866L, approx_count_distinct(OWNERSHIP-IND#139, 0.05, 0, 0) AS OWNERSHIP-IND_dist#972L, approx_count_distinct(ACCOUNT-STATUS#140, 0.05, 0, 0) AS ACCOUNT-STATUS_dist#1078L, approx_count_distinct(DISBURSED-DT#141, 0.05, 0, 0) AS DISBURSED-DT_dist#1184L, approx_count_distinct(CLOSE-DT#142, 0.05, 0, 0) AS CLOSE-DT_dist#1290L, approx_count_distinct(LAST-PAYMENT-DATE#143, 0.05, 0, 0) AS LAST-PAYMENT-DATE_dist#1396L, approx_count_distinct(INSTALLMENT-FREQUENCY#148, 0.05, 0, 0) AS INSTALLMENT-FREQUENCY_dist#1502L, approx_count_distinct(ASSET_CLASS#151, 0.05, 0, 0) AS ASSET_CLASS_dist#1608L, approx_count_distinct(REPORTED DATE - HIST#152, 0.05, 0, 0) AS REPORTED DATE - HIST_dist#1714L, approx_count_distinct(DPD - HIST#153, 0.05, 0, 0) AS DPD - HIST_dist#1820L, approx_count_distinct(CUR BAL - HIST#154, 0.05, 0, 0) AS CUR BAL - HIST_dist#1926L, ... 3 more fields]
#                   :           +- Filter isnotnull(ts#158-T5000ms)
#                   :              +- Project [named_struct(start, precisetimestampconversion(((((CASE WHEN (cast(CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) as double) = (cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) THEN (CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) + cast(1 as bigint)) ELSE CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) END + cast(0 as bigint)) - cast(1 as bigint)) * 30000000) + 0), LongType, TimestampType), end, precisetimestampconversion((((((CASE WHEN (cast(CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) as double) = (cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) THEN (CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) + cast(1 as bigint)) ELSE CEIL((cast((precisetimestampconversion(ts#158-T5000ms, TimestampType, LongType) - 0) as double) / cast(30000000 as double))) END + cast(0 as bigint)) - cast(1 as bigint)) * 30000000) + 0) + 30000000), LongType, TimestampType)) AS window#4013-T5000ms, ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#373, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, ... 3 more fields]
#                   :                 +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, cast(split(INSTALLMENT-AMT#346, /, -1)[0] as int) AS INSTALLMENT-AMT#373, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                    +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, regexp_replace(INSTALLMENT-AMT#146, ,, ) AS INSTALLMENT-AMT#346, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                       +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, cast(regexp_replace(CREDIT-LIMIT/SANC AMT#144, ,, ) as int) AS CREDIT-LIMIT/SANC AMT#319, DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#146, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                          +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, cast(regexp_replace(DISBURSED-AMT/HIGH CREDIT#145, ,, ) as int) AS DISBURSED-AMT/HIGH CREDIT#292, INSTALLMENT-AMT#146, CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                             +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, cast(regexp_replace(CURRENT-BAL#147, ,, ) as int) AS CURRENT-BAL#265, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                                +- Project [ID#133, SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, CURRENT-BAL#147, INSTALLMENT-FREQUENCY#148, cast(regexp_replace(OVERDUE-AMT#149, ,, ) as int) AS OVERDUE-AMT#238, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                                   +- Project [ID#133, CASE WHEN (SELF-INDICATOR#134 = TRUE) THEN 1 ELSE 0 END AS SELF-INDICATOR#211, MATCH-TYPE#135, ACCT-TYPE#136, CONTRIBUTOR-TYPE#137, DATE-REPORTED#138, OWNERSHIP-IND#139, ACCOUNT-STATUS#140, DISBURSED-DT#141, CLOSE-DT#142, LAST-PAYMENT-DATE#143, CREDIT-LIMIT/SANC AMT#144, DISBURSED-AMT/HIGH CREDIT#145, INSTALLMENT-AMT#146, CURRENT-BAL#147, INSTALLMENT-FREQUENCY#148, OVERDUE-AMT#149, WRITE-OFF-AMT#150, ASSET_CLASS#151, REPORTED DATE - HIST#152, DPD - HIST#153, CUR BAL - HIST#154, AMT OVERDUE - HIST#155, AMT PAID - HIST#156, ... 2 more fields]
#                   :                                      +- EventTimeWatermark ts#158: timestamp, 5 seconds
#                   :                                         +- Project [unnested_value#50.ID AS ID#133, unnested_value#50.SELF-INDICATOR AS SELF-INDICATOR#134, unnested_value#50.MATCH-TYPE AS MATCH-TYPE#135, unnested_value#50.ACCT-TYPE AS ACCT-TYPE#136, unnested_value#50.CONTRIBUTOR-TYPE AS CONTRIBUTOR-TYPE#137, unnested_value#50.DATE-REPORTED AS DATE-REPORTED#138, unnested_value#50.OWNERSHIP-IND AS OWNERSHIP-IND#139, unnested_value#50.ACCOUNT-STATUS AS ACCOUNT-STATUS#140, unnested_value#50.DISBURSED-DT AS DISBURSED-DT#141, unnested_value#50.CLOSE-DT AS CLOSE-DT#142, unnested_value#50.LAST-PAYMENT-DATE AS LAST-PAYMENT-DATE#143, unnested_value#50.CREDIT-LIMIT/SANC AMT AS CREDIT-LIMIT/SANC AMT#144, unnested_value#50.DISBURSED-AMT/HIGH CREDIT AS DISBURSED-AMT/HIGH CREDIT#145, unnested_value#50.INSTALLMENT-AMT AS INSTALLMENT-AMT#146, unnested_value#50.CURRENT-BAL AS CURRENT-BAL#147, unnested_value#50.INSTALLMENT-FREQUENCY AS INSTALLMENT-FREQUENCY#148, unnested_value#50.OVERDUE-AMT AS OVERDUE-AMT#149, unnested_value#50.WRITE-OFF-AMT AS WRITE-OFF-AMT#150, unnested_value#50.ASSET_CLASS AS ASSET_CLASS#151, unnested_value#50.REPORTED DATE - HIST AS REPORTED DATE - HIST#152, unnested_value#50.DPD - HIST AS DPD - HIST#153, unnested_value#50.CUR BAL - HIST AS CUR BAL - HIST#154, unnested_value#50.AMT OVERDUE - HIST AS AMT OVERDUE - HIST#155, unnested_value#50.AMT PAID - HIST AS AMT PAID - HIST#156, ... 2 more fields]
#                   :                                            +- Project [unnested_value#50]
#                   :                                               +- Generate explode(parsed_value#44), false, [unnested_value#50]
#                   :                                                  +- Project [from_json(ArrayType(StructType(StructField(ID,IntegerType,true), StructField(SELF-INDICATOR,StringType,true), StructField(MATCH-TYPE,StringType,true), StructField(ACCT-TYPE,StringType,true), StructField(CONTRIBUTOR-TYPE,StringType,true), StructField(DATE-REPORTED,StringType,true), StructField(OWNERSHIP-IND,StringType,true), StructField(ACCOUNT-STATUS,StringType,true), StructField(DISBURSED-DT,StringType,true), StructField(CLOSE-DT,StringType,true), StructField(LAST-PAYMENT-DATE,StringType,true), StructField(CREDIT-LIMIT/SANC AMT,StringType,true), StructField(DISBURSED-AMT/HIGH CREDIT,StringType,true), StructField(INSTALLMENT-AMT,StringType,true), StructField(CURRENT-BAL,StringType,true), StructField(INSTALLMENT-FREQUENCY,StringType,true), StructField(OVERDUE-AMT,StringType,true), StructField(WRITE-OFF-AMT,IntegerType,true), StructField(ASSET_CLASS,StringType,true), StructField(REPORTED DATE - HIST,StringType,true), StructField(DPD - HIST,StringType,true), StructField(CUR BAL - HIST,StringType,true), StructField(AMT OVERDUE - HIST,StringType,true), StructField(AMT PAID - HIST,StringType,true), StructField(TENURE,IntegerType,true), StructField(ts,TimestampType,true)),true), cast(value#29 as string), Some(UTC)) AS parsed_value#44]
#                   :                                                     +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@791247c9, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@2b3dc35f, org.apache.spark.sql.util.CaseInsensitiveStringMap@d7a373e3, [key#28, value#29, topic#30, partition#31, offset#32L, timestamp#33, timestampType#34], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@17ec9b9c,kafka,List(),None,List(),None,Map(subscribe -> bureau_data, kafka.bootstrap.servers -> localhost:9092),None), kafka, [key#21, value#22, topic#23, partition#24, offset#25L, timestamp#26, timestampType#27]
#                   +- Project [unnested_value#47.ID AS ID#52, unnested_value#47.Frequency AS Frequency#53, unnested_value#47.InstlmentMode AS InstlmentMode#54, unnested_value#47.LoanStatus AS LoanStatus#55, unnested_value#47.PaymentMode AS PaymentMode#56, unnested_value#47.BranchID AS BranchID#57, unnested_value#47.Area AS Area#58, unnested_value#47.Tenure AS Tenure#59, unnested_value#47.AssetCost AS AssetCost#60, unnested_value#47.AmountFinance AS AmountFinance#61, unnested_value#47.DisbursalAmount AS DisbursalAmount#62, unnested_value#47.EMI AS EMI#63, unnested_value#47.DisbursalDate AS DisbursalDate#64, unnested_value#47.MaturityDAte AS MaturityDAte#65, unnested_value#47.AuthDate AS AuthDate#66, unnested_value#47.AssetID AS AssetID#67, unnested_value#47.ManufacturerID AS ManufacturerID#68, unnested_value#47.SupplierID AS SupplierID#69, unnested_value#47.LTV AS LTV#70, unnested_value#47.SEX AS SEX#71, unnested_value#47.AGE AS AGE#72, unnested_value#47.MonthlyIncome AS MonthlyIncome#73, unnested_value#47.City AS City#74, unnested_value#47.State AS State#75, ... 3 more fields]
#                      +- Project [unnested_value#47]
#                         +- Generate explode(parsed_value#42), false, [unnested_value#47]
#                            +- Project [from_json(ArrayType(StructType(StructField(ID,IntegerType,true), StructField(Frequency,StringType,true), StructField(InstlmentMode,StringType,true), StructField(LoanStatus,StringType,true), StructField(PaymentMode,StringType,true), StructField(BranchID,StringType,true), StructField(Area,StringType,true), StructField(Tenure,IntegerType,true), StructField(AssetCost,IntegerType,true), StructField(AmountFinance,DoubleType,true), StructField(DisbursalAmount,DoubleType,true), StructField(EMI,DoubleType,true), StructField(DisbursalDate,StringType,true), StructField(MaturityDAte,StringType,true), StructField(AuthDate,StringType,true), StructField(AssetID,StringType,true), StructField(ManufacturerID,StringType,true), StructField(SupplierID,StringType,true), StructField(LTV,DoubleType,true), StructField(SEX,StringType,true), StructField(AGE,IntegerType,true), StructField(MonthlyIncome,DoubleType,true), StructField(City,StringType,true), StructField(State,StringType,true), StructField(ZiPCODE,IntegerType,true), StructField(Top-up Month,StringType,true), StructField(ts,TimestampType,true)),true), cast(value#8 as string), Some(UTC)) AS parsed_value#42]
#                               +- StreamingRelationV2 org.apache.spark.sql.kafka010.KafkaSourceProvider@1cae2096, kafka, org.apache.spark.sql.kafka010.KafkaSourceProvider$KafkaTable@1fc7ad21, org.apache.spark.sql.util.CaseInsensitiveStringMap@152a74ff, [key#7, value#8, topic#9, partition#10, offset#11L, timestamp#12, timestampType#13], StreamingRelation DataSource(org.apache.spark.sql.SparkSession@17ec9b9c,kafka,List(),None,List(),None,Map(subscribe -> customer_data, kafka.bootstrap.servers -> localhost:9092),None), kafka, [key#0, value#1, topic#2, partition#3, offset#4L, timestamp#5, timestampType#6]

# %%
query1.stop()
# Out:
# 22/10/23 05:49:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:06 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:06 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:08 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:08 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:09 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:09 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:12 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:12 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:19 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:19 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:25 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:25 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:27 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:27 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:30 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:30 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:31 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:31 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:33 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:33 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:34 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:34 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:36 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:36 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:37 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:37 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:39 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:39 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:40 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:40 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:41 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:41 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:42 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:42 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:43 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:43 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:44 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:44 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:45 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:45 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:46 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:47 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:47 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:48 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:48 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:49 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:49 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:50 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:51 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:51 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:52 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:52 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:53 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:54 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:54 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:55 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:56 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:56 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:57 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:57 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:58 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:49:59 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:49:59 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:00 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:00 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:01 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:01 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:02 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:03 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:04 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:05 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:07 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:09 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:09 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:10 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:11 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:12 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:12 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:13 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:14 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:50:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:50:15 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# ...
# 22/10/23 05:51:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:17 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:18 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:19 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:19 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:20 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:21 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:22 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:23 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:24 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:25 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:25 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:26 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:27 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:27 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:28 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:28 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:29 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:30 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:30 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:31 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:31 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:32 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:33 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:33 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:34 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:34 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:35 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:36 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:36 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:37 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:37 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:38 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:39 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:39 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:40 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:40 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected
# 22/10/23 05:51:41 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Connection to node -1 (localhost/127.0.0.1:9092) could not be established. Broker may not be available.
# 22/10/23 05:51:41 WARN NetworkClient: [Consumer clientId=consumer-spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0-1, groupId=spark-kafka-source-4c061b94-a7ca-468d-b53d-001ed2c84507-1480152181-driver-0] Bootstrap broker localhost:9092 (id: -1 rack: null) disconnected

# %% [markdown]
# ### References
# to set UTC
# https://stackoverflow.com/questions/49644232/how-to-set-timezone-to-utc-in-apache-spark
#
# For Watermark
# https://spark.apache.org/docs/3.1.1/api/python/reference/api/pyspark.sql.DataFrame.withWatermark.html
#
# For sum agg
# https://www.anycodings.com/1questions/762375/pyspark-loop-in-groupby-aggregate-function
#
# For join
# https://spark.apache.org/docs/latest/structured-streaming-programming-guide.html#join-operations
#
# For loading ML model
# https://stackoverflow.com/questions/57038445/load-model-pyspark
#
# For collecting set  values
# https://sparkbyexamples.com/spark/spark-collect-list-and-collect-set-functions/
#
# for JSON
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_json.html
